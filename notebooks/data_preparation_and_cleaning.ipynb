# %%
import os 
os.chdir('../scripts')

# %%
import importlib
import extract_data as ed
import data_preparation as dp
from dotenv import load_dotenv

# %%
load_dotenv()

db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")
db_port = os.getenv("DB_PORT")
db_name = os.getenv("DB_NAME")

# db_url = 'postgresql://postgres:teddy4309@localhost:5432/telecom' 
db_url = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
query = 'SELECT * FROM xdr_data'

# %%
importlib.reload(dp)
data = dp.load_data(db_url, query)
data.head()
data.describe()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# ...

# %%
importlib.reload(dp)
cleaned_data = dp.clean_data(data)

# %%
cleaned_data.head()
cleaned_data.describe()
# Out:
#           Bearer Id       Start ms         End ms      Dur. (ms)  \
# count  1.500010e+05  150001.000000  150001.000000  150001.000000
# mean   1.013887e+19     499.188200     498.800880   99572.233100
# std    2.883600e+18     288.610872     288.096693   59084.521408
# min    6.917538e+18       0.000000       0.000000    7142.000000
# 25%    7.349883e+18     250.000000     251.000000   57442.000000
# 50%    7.349883e+18     499.000000     500.000000   86399.000000
# 75%    1.304243e+19     749.000000     750.000000  132430.000000
# max    1.318654e+19     999.000000     999.000000  244914.875000
#
#                IMSI  MSISDN/Number          IMEI  Avg RTT DL (ms)  \
# count  1.500010e+05   1.500010e+05  1.500010e+05    150001.000000
# mean   2.082015e+14   3.366910e+10  4.847455e+13        56.427864
# std    3.924973e+08   3.408986e+07  2.237359e+13        29.985572
# min    2.082008e+14   3.360300e+10  4.400152e+11         0.000000
# ...

# %%
importlib.reload(dp)
handset_freq = dp.aggregate_handset_frequency(cleaned_data)

# %%
importlib.reload(dp)
dp.plot_top_handsets(handset_freq)

# %%
importlib.reload(dp)
manufacturer_freq = dp.aggregate_manufacturer_frequency(cleaned_data)

# %%
dp.plot_top_manufacturers(manufacturer_freq)

# %%
importlib.reload(dp)
dp.plot_top_handsets_per_manufacturer(cleaned_data)

# %%
importlib.reload(dp)
aggregated_data = dp.aggregate_user_behavior(data)

# %%
aggregated_data.head()
# Out:
#    MSISDN/Number  xDR_sessions  session_duration  Total DL (Bytes)  \
# 0   3.360100e+10             1          116720.0      8.426375e+08
# 1   3.360100e+10             1          181230.0      1.207552e+08
# 2   3.360100e+10             1          134969.0      5.566597e+08
# 3   3.360101e+10             1           49878.0      4.019932e+08
# 4   3.360101e+10             2           37104.0      1.363130e+09
#
#    Total UL (Bytes)  Social Media DL (Bytes)  Social Media UL (Bytes)  \
# 0        36053108.0                2206504.0                  25631.0
# 1        36104459.0                2598548.0                  62017.0
# 2        39306820.0                3148004.0                  47619.0
# 3        20327526.0                 251469.0                  28825.0
# 4        94280527.0                2861230.0                  51312.0
#
#    Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  Email UL (Bytes)  \
# ...

# %%
importlib.reload(dp)
dp.graphical_univariate_analysis(data)

# %%
importlib.reload(dp)
dp.bivariate_analysis(data)

# %%
importlib.reload(dp)
correlation_matrix = dp.correlation_analysis(data)
correlation_matrix
# Out:
#                                           Bearer Id  Start ms    End ms  \
# Bearer Id                                  1.000000  0.002961 -0.001219
# Start ms                                   0.002961  1.000000  0.120945
# End ms                                    -0.001219  0.120945  1.000000
# Dur. (ms)                                  0.007515  0.001287 -0.001302
# IMSI                                       0.000152 -0.000054  0.000328
# MSISDN/Number                             -0.003307 -0.001021 -0.001890
# IMEI                                       0.164054 -0.001133 -0.000032
# Avg RTT DL (ms)                           -0.022561  0.004141 -0.005287
# Avg RTT UL (ms)                            0.034924 -0.002221 -0.002607
# Avg Bearer TP DL (kbps)                    0.063973 -0.000690  0.000694
# Avg Bearer TP UL (kbps)                    0.048123 -0.001268  0.000687
# TCP DL Retrans. Vol (Bytes)                0.019186  0.000328  0.004941
# ...

# %%
importlib.reload(dp)
dimentionality_reduction = dp.dimensionality_reduction(data)
dimentionality_reduction
# Out:
#                  PC1           PC2
# 0      -3.592666e+00  3.981795e+00
# 1      -2.909312e+00  2.946994e+00
# 2      -2.924152e+00  2.985149e+00
# 3      -2.895557e+00  2.871820e+00
# 4      -2.550674e+00  2.377623e+00
# ...              ...           ...
# 149996 -1.261644e+00  2.351809e-01
# 149997 -1.284197e+00  2.854596e-01
# 149998 -1.208248e+00  2.521313e-01
# 149999 -7.999168e-01  9.004466e-02
# 150000  8.493295e-16 -4.701878e-15
#
# [150001 rows x 2 columns]
